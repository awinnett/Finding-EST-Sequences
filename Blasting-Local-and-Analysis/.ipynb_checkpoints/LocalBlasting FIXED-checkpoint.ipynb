# %% [raw]
# /#inputfile = "QGG24G02.yg.ab1_CLS_S3_Contig10858_LettuceNCBI.fasta"
# #outputfile = inputfile+"_"+"refseqBLASTresults.csv"
#
# inputfile = "C:\Users\Alex\Desktop\Work\Research\Lettuce\"
# outputfile = "C:\Users\Alex\Desktop\Work\Research\Lettuce\"
#
# blastn_cline = NcbiblastnCommandline(query=inputfile, db="refseqplant", evalue=0.001, outfmt='"10 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore sgi sacc stitle"', out=outputfile)
# #blastn_cline = NcbiblastnCommandline(query=inputfile, db="refseqplant", evalue=0.001, outfmt="10 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore stitle", out=outputfile)
# blastn_cline
# #can use std for all qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore
# #download one fasta seq from NCBI for a plant and blast it against this to see the difference between stitle and salltitles
# print(blastn_cline)
# stdout, stderr = blastn_cline()

# %% [markdown]
# ###### blastn –out C:\PATH\OUTPUTFILENAME.csv -outfmt "10 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore sgi sacc stitle" –query C:\PATH\INPUTFILENAME.txt -db refseqplant -evalue 0.001

# %% [raw]
# TYPE THE ORGANISM NAME BELOW

# %%
from Bio import SeqIO
import csv
from Bio import Entrez
from Bio.Blast import NCBIWWW

# %%
Entrez.email = "alexander.winnett001@umb.edu"


localblastresults = "C:\Users\Alex\Desktop\Work\Research\Lettuce\GitHub\Finding-EST-Sequences\TESTLOCALBLAST_QGG24G02.yg.ab1_CLS_S3_Contig10858_LettuceNCBI.csv"
outputfile = "C:\Users\Alex\Desktop\Work\Research\Lettuce\GitHub\Finding-EST-Sequences\CORRECTEDTESTLOCALBLAST_QGG24G02.yg.ab1_CLS_S3_Contig10858_LettuceNCBI.csv"

organisms = []
mismatch = 0
duplicates = {}
rows = 0 #limiter for testing
with open(localblastresults, 'rb') as csvfile: #open the CSV file generated by local blast
    record = csv.reader(csvfile)#name the records
    output = csv.writer(open(outputfile, 'wb'))
    for row in record: #for each entry in the spreadsheet
        accession = row[12] #identify the accession number
        handle = Entrez.efetch(db="nucleotide", rettype="gb", retmode="text", id=accession) # db = database to query, rettype = retrieval type, retmode = retrieval mode 
        seq_record = SeqIO.read(handle, "gb") #read the contents "fetched" from NCBI
        org = seq_record.annotations['organism'] #pulls the organism name from the BLAST
        stitle = row[14] #STITLE contains the org name and the name of the match
        rows += 1  #for testing
        print rows, "rows analyzed"
        #assert rows < 4 #LIMITER FOR TESTING#################################################
        if org not in organisms:
            organisms.append(org) #add that organism to the dictionary
            print organisms
            duplicates[org] = 0
        elif org in organisms:
            for name in duplicates:
                if org == name:
                    duplicatenumber = duplicates[org] + 1
                    duplicates[org] = duplicatenumber  #keeping tabs of how many times an organism is hit, could be interesting
            print "duplicate found"
        if org not in stitle: 
            mismatch += 1 #this is strange, and we should know how many times this occurs
            print mismatch, "mismatched"
        newlist = row + [org]
        output.writerow(newlist)
        handle.close()
ouput.close()
# Out:
# 1 rows analyzed
# ['Ricinus communis']
# 2
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera']
# 3
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa']
# 4
#  rows analyzed
# duplicate found
# 5
#  rows analyzed
# duplicate found
# 6
#  rows analyzed
# duplicate found
# 7
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum']
# 8
#  rows analyzed
# duplicate found
# 9
#  rows analyzed
# duplicate found
# 10
#  rows analyzed
# duplicate found
# 11
#  rows analyzed
# duplicate found
# 12
#  rows analyzed
# duplicate found
# 13
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum']
# 14
#  rows analyzed
# duplicate found
# 15
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera']
# 16
#  rows analyzed
# duplicate found
# 17
#  rows analyzed
# duplicate found
# 18
#  rows analyzed
# duplicate found
# 19
#  rows analyzed
# duplicate found
# 20
#  rows analyzed
# duplicate found
# 21
#  rows analyzed
# duplicate found
# 22
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum']
# 23
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max']
# 24
#  rows analyzed
# duplicate found
# 25
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus']
# 26
#  rows analyzed
# duplicate found
# 27
#  rows analyzed
# duplicate found
# 28
#  rows analyzed
# duplicate found
# 29
#  rows analyzed
# duplicate found
# 30
#  rows analyzed
# duplicate found
# 31
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana']
# 32
#  rows analyzed
# duplicate found
# 33
#  rows analyzed
# duplicate found
# 34
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula']
# 35
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca']
# 36
#  rows analyzed
# duplicate found
# 37
#  rows analyzed
# duplicate found
# 38
#  rows analyzed
# duplicate found
# 39
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica']
# 1 mismatched
# 40
#  rows analyzed
# duplicate found
# 41
#  rows analyzed
# duplicate found
# 42
#  rows analyzed
# duplicate found
# 43
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella']
# 44
#  rows analyzed
# duplicate found
# 45
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarp
# duplicate found
# 4 mismatched
# 111
#  rows analyzed
# duplicate found
# 112
#  rows analyzed
# duplicate found
# 113
#  rows analyzed
# duplicate found
# 114
#  rows analyzed
# duplicate found
# 115
#  rows analyzed
# duplicate found
# 116
#  rows analyzed
# duplicate found
# 117
#  rows analyzed
# duplicate found
# 118
#  rows analyzed
# duplicate found
# 119
#  rows analyzed
# duplicate found
# 120
#  rows analyzed
# duplicate found
# 121
#  rows analyzed
# duplicate found
# 122
#  rows analyzed
# duplicate found
# 123
#  rows analyzed
# duplicate found
# 124
#  rows analyzed
# duplicate found
# 125
#  rows analyzed
# duplicate found
# 126
#  rows analyzed
# duplicate found
# 127
#  rows analyzed
# duplicate found
# 128
#  rows analyzed
# duplicate found
# 129
#  rows analyzed
# duplicate found
# 130
#  rows analyzed
# duplicate found
# 131
#  rows analyzed
# duplicate found
# 132
#  rows analyzed
# duplicate found
# 133
#  rows analyzed
# duplicate found
# 134
#  rows analyzed
# duplicate found
# 135
#  rows analyzed
# duplicate found
# 136
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao']
# 137
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo']
# 138
#  rows analyzed
# duplicate found
# 139
#  rows analyzed
# duplicate found
# 140
#  rows analyzed
# duplicate found
# 141
#  rows analyzed
# duplicate found
# 142
#  rows analyzed
# duplicate found
# 5 mismatched
# 143
#  rows analyzed
# duplicate found
# 6 mismatched
# 144
#  rows analyzed
# duplicate found
# 145
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis']
# 146
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina']
# 147
#  rows analyzed
# duplicate found
# 148
#  rows analyzed
# duplicate found
# 7 mismatched
# 149
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume']
# 150
#  rows analyzed
# duplicate found
# 151
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda']
# 152
#  rows analyzed
# duplicate found
# 8 mismatched
# 153
#  rows analyzed
# duplicate found
# 154
#  rows analyzed
# duplicate found
# 155
#  rows analyzed
# duplicate found
# 156
#  rows analyzed
# duplicate found
# 9 mismatched
# 157
#  rows analyzed
# duplicate found
# 158
#  rows analyzed
# duplicate found
# 159
#  rows analyzed
# duplicate found
# 160
#  rows analyzed
# duplicate found
# 161
#  rows analyzed
# duplicate found
# 162
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica']
# 163
#  rows analyzed
# duplicate found
# 164
#  rows analyzed
# duplicate found
# 165
#  rows analyzed
# duplicate found
# 166
#  rows analyzed
# duplicate found
# 167
#  rows analyzed
# duplicate found
# 168
#  rows analyzed
# duplicate found
# 169
#  rows analyzed
# duplicate found
# 170
#  rows analyzed
# duplicate found
# 171
#  rows analyzed
# duplicate found
# 172
#  rows analyzed
# duplicate found
# 173
#  rows analyzed
# duplicate found
# 174
#  rows analyzed
# duplicate found
# 175
#  rows analyzed
# duplicate found
# 176
#  rows analyzed
# duplicate found
# 177
#  rows analyzed
# duplicate found
# 178
#  rows analyzed
# duplicate found
# 179
#  rows analyzed
# duplicate found
# 180
#  rows analyzed
# duplicate found
# 181
#  rows analyzed
# duplicate found
# 182
#  rows analyzed
# duplicate found
# 183
#  rows analyzed
# duplicate found
# 184
#  rows analyzed
# duplicate found
# 185
#  rows analyzed
# duplicate found
# 186
#  rows analyzed
# duplicate found
# 187
#  rows analyzed
# duplicate found
# 188
#  rows analyzed
# duplicate found
# 189
#  rows analyzed
# duplicate found
# 190
#  rows analyzed
# duplicate found
# 191
#  rows analyzed
# duplicate found
# 192
#  rows analyzed
# duplicate found
# 193
#  rows analyzed
# duplicate found
# 194
#  rows analyzed
# duplicate found
# 195
#  rows analyzed
# duplicate found
# 196
#  rows analyzed
# duplicate found
# 197
#  rows analyzed
# duplicate found
# 198
#  rows analyzed
# duplicate found
# 199
#  rows analyzed
# duplicate found
# 200
#  rows analyzed
# duplicate found
# 201
#  rows analyzed
# duplicate found
# 202
#  rows analyzed
# duplicate found
# 203
#  rows analyzed
# duplicate found
# 204
#  rows analyzed
# duplicate found
# 205
#  rows analyzed
# duplicate found
# 206
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum']
# 207
#  rows analyzed
# duplicate found
# 208
#  rows analyzed
# duplicate found
# 209
#  rows analyzed
# duplicate found
# 210
#  rows analyzed
# duplicate found
# 211
#  rows analyzed
# duplicate found
# 212
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris']
# 213
#  rows analyzed
# duplicate found
# 214
#  rows analyzed
# duplicate found
# 215
#  rows analyzed
# duplicate found
# 216
#  rows analyzed
# duplicate found
# 217
#  rows analyzed
# duplicate found
# 218
#  rows analyzed
# duplicate found
# 219
#  rows analyzed
# duplicate found
# 220
#  rows analyzed
# duplicate found
# 221
#  rows analyzed
# duplicate found
# 222
#  rows analyzed
# duplicate found
# 223
#  rows analyzed
# duplicate found
# 224
#  rows analyzed
# duplicate found
# 225
#  rows analyzed
# duplicate found
# 226
#  rows analyzed
# duplicate found
# 227
#  rows analyzed
# duplicate found
# 228
#  rows analyzed
# duplicate found
# 229
#  rows analyzed
# duplicate found
# 230
#  rows analyzed
# duplicate found
# 231
#  rows analyzed
# duplicate found
# 232
#  rows analyzed
# duplicate found
# 233
#  rows analyzed
# duplicate found
# 234
#  rows analyzed
# duplicate found
# 235
#  rows analyzed
# duplicate found
# 236
#  rows analyzed
# duplicate found
# 237
#  rows analyzed
# duplicate found
# 238
#  rows analyzed
# duplicate found
# 239
#  rows analyzed
# duplicate found
# 240
#  rows analyzed
# duplicate found
# 241
#  rows analyzed
# duplicate found
# 242
#  rows analyzed
# duplicate found
# 243
#  rows analyzed
# duplicate found
# 244
#  rows analyzed
# duplicate found
# 245
#  rows analyzed
# duplicate found
# 246
#  rows analyzed
# duplicate found
# 10 mismatched
# 247
#  rows analyzed
# duplicate found
# 248
#  rows analyzed
# duplicate found
# 249
#  rows analyzed
# duplicate found
# 250
#  rows analyzed
# duplicate found
# 251
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha']
# 252
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor']
# 253
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays']
# 254
#  rows analyzed
# duplicate found
# 255
#  rows analyzed
# duplicate found
# 256
#  rows analyzed
# duplicate found
# 257
#  rows analyzed
# duplicate found
# 258
#  rows analyzed
# duplicate found
# 259
#  rows analyzed
# duplicate found
# 260
#  rows analyzed
# duplicate found
# 261
#  rows analyzed
# duplicate found
# 262
#  rows analyzed
# duplicate found
# 263
#  rows analyzed
# duplicate found
# 264
#  rows analyzed
# duplicate found
# 265
#  rows analyzed
# duplicate found
# 266
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon']
# 267
#  rows analyzed
# duplicate found
# 268
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon', 'Oryza sativa Japonica Group']
# 269
#  rows analyzed
# duplicate found
# 270
#  rows analyzed
# duplicate found
# 271
#  rows analyzed
# duplicate found
# 272
#  rows analyzed
# duplicate found
# 273
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon', 'Oryza sativa Japonica Group', 'Prunus persica']
# 274
#  rows analyzed
# duplicate found
# 11 mismatched
# 275
#  rows analyzed
# duplicate found
# 276
#  rows analyzed
# duplicate found
# 277
#  rows analyzed
# duplicate found
# 278
#  rows analyzed
# duplicate found
# 279
#  rows analyzed
# duplicate found
# 280
#  rows analyzed
# duplicate found
# 281
#  rows analyzed
# duplicate found
# 282
#  rows analyzed
# duplicate found
# 283
#  rows analyzed
# duplicate found
# 284
#  rows analyzed
# duplicate found
# 285
#  rows analyzed
# duplicate found
# 286
#  rows analyzed
# duplicate found
# 287
#  rows analyzed
# duplicate found
# 288
#  rows analyzed
# duplicate found
# 289
#  rows analyzed
# duplicate found
# 290
#  rows analyzed
# duplicate found
# 291
#  rows analyzed
# duplicate found
# 292
#  rows analyzed
# duplicate found
# 293
#  rows analyzed
# duplicate found
# 294
#  rows analyzed
# duplicate found
# 295
#  rows analyzed
# duplicate found
# 296
#  rows analyzed
# duplicate found
# 297
#  rows analyzed
# duplicate found
# 298
#  rows analyzed
# duplicate found
# 299
#  rows analyzed
# duplicate found
# 300
#  rows analyzed
# duplicate found
# 301
#  rows analyzed
# duplicate found
# 302
#  rows analyzed
# duplicate found
# 303
#  rows analyzed
# duplicate found
# 304
#  rows analyzed
# duplicate found
# 305
#  rows analyzed
# duplicate found
# 306
#  rows analyzed
# duplicate found
# 307
#  rows analyzed
# duplicate found
# 308
#  rows analyzed
# duplicate found
# 12 mismatched
# 309
#  rows analyzed
# duplicate found
# 310
#  rows analyzed
# duplicate found
# 311
#  rows analyzed
# duplicate found
# 312
#  rows analyzed
# duplicate found
# 313
#  rows analyzed
# duplicate found
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon', 'Oryza sativa Japonica Group', 'Prunus persica', 'Micromonas sp. RCC299']
# 465
#  rows analyzed
# duplicate found
# 466
#  rows analyzed
# duplicate found
# 467
#  rows analyzed
# duplicate found
# 468
#  rows analyzed
# duplicate found
# 469
#  rows analyzed
# duplicate found
# 470
#  rows analyzed
# duplicate found
# 471
#  rows analyzed
# duplicate found
# 472
#  rows analyzed
# duplicate found
# 473
#  rows analyzed
# duplicate found
# 474
#  rows analyzed
# duplicate found
# 475
#  rows analyzed
# duplicate found
# 476
#  rows analyzed
# duplicate found
# 477
#  rows analyzed
# duplicate found
# 478
#  rows analyzed
# duplicate found
# 479
#  rows analyzed
# duplicate found
# 480
#  rows analyzed
# duplicate found
# 481
#  rows analyzed
# duplicate found
# 482
#  rows analyzed
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon', 'Oryza sativa Japonica Group', 'Prunus persica', 'Micromonas sp. RCC299', 'Selaginella moellendorffii']
# 483
#  rows analyzed
# duplicate found
# 484
#  rows analyzed
# duplicate found
# 485
#  rows analyzed
# duplicate found
# 486
#  rows analyzed
# duplicate found
# 487
#  rows analyzed
# duplicate found
# 488
#  rows analyzed
# duplicate found
# 489
#  rows analyzed
# duplicate found
# 490
#  rows analyzed
# duplicate found
# 491
#  rows analyzed
# duplicate found
# 492
#  rows analyzed
# duplicate found
# 493
#  rows analyzed
# duplicate found
# 494
#  rows analyzed
# duplicate found
# 495
#  rows analyzed
# duplicate found
# 496
#  rows analyzed
# duplicate found
# 497
#  rows analyzed
# duplicate found
# 498
#  rows analyzed
# duplicate found
# 499
#  rows analyzed
# duplicate found
# 500
#  rows analyzed
# duplicate found
# 501
#  rows analyzed
# duplicate found
# 502
#  rows analyzed
# duplicate found
# 503
#  rows analyzed
# duplicate found
# 504
#  rows analyzed
# duplicate found
# 505
#  rows analyzed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d6bb8125703d> in <module>()
#      37         output.writerow(newlist)
#      38         handle.close()
# ---> 39 ouput.close()
#
# NameError: name 'ouput' is not defined

# %%
print "Organism Hits"
print organisms #contains all hit organisms only once
print
print "Mismatches:", 
print mismatch #number of times an org name isn't in stitle
print "out of", rows
percent = ((float(mismatch)/rows)*100)
print percent, "% mismatched"
print 
print "Duplication Trends" 
print duplicates #dictionary detailing how many times each organism was a blast hit
# Out:
# Organism Hits
# ['Ricinus communis', 'Vitis vinifera', 'Populus trichocarpa', 'Cicer arietinum', 'Eutrema salsugineum', 'Phoenix dactylifera', 'Solanum lycopersicum', 'Glycine max', 'Cucumis sativus', 'Arabidopsis thaliana', 'Medicago truncatula', 'Fragaria vesca subsp. vesca', 'Malus domestica', 'Capsella rubella', 'Arabidopsis lyrata subsp. lyrata', 'Theobroma cacao', 'Cucumis melo', 'Citrus sinensis', 'Citrus clementina', 'Prunus mume', 'Amborella trichopoda', 'Setaria italica', 'Solanum tuberosum', 'Phaseolus vulgaris', 'Oryza brachyantha', 'Sorghum bicolor', 'Zea mays', 'Brachypodium distachyon', 'Oryza sativa Japonica Group', 'Prunus persica', 'Micromonas sp. RCC299', 'Selaginella moellendorffii']
#
# Mismatches: 16
# out of 582
# 2.74914089347 % mismatched
#
# Duplication Trends
# {'Solanum lycopersicum': 40, 'Phoenix dactylifera': 7, 'Fragaria vesca subsp. vesca': 14, 'Cicer arietinum': 28, 'Vitis vinifera': 47, 'Amborella trichopoda': 5, 'Citrus sinensis': 11, 'Brachypodium distachyon': 6, 'Malus domestica': 15, 'Prunus persica': 6, 'Sorghum bicolor': 1, 'Phaseolus vulgaris': 29, 'Eutrema salsugineum': 5, 'Oryza sativa Japonica Group': 1, 'Arabidopsis lyrata subsp. lyrata': 6, 'Citrus clementina': 11, 'Solanum tuberosum': 26, 'Selaginella moellendorffii': 5, 'Glycine max': 62, 'Ricinus communis': 13, 'Zea mays': 4, 'Cucumis sativus': 31, 'Setaria italica': 28, 'Populus trichocarpa': 16, 'Capsella rubella': 15, 'Medicago truncatula': 24, 'Micromonas sp. RCC299': 1, 'Arabidopsis thaliana': 35, 'Prunus mume': 3, 'Theobroma cacao': 43, 'Oryza brachyantha': 3, 'Cucumis melo': 9}

# %% [raw]
# OPEN CSV file
# look at ones with only E value of 0,
# then by organism too - but to use that, we'd have to have it search/slice for just the org name
#      to know what org names we can look from, we need the full list of organisms in the plant db
#         cut out the GeneID's so row# = gId --> use the gene ID to look up in NCBI, then from there, pull attribute from record that is = to organism
#         take that organism string and look for it in stitle (var = re.search(~~~, instring)) var.start() var.end()
#             ask if start is always at the beginning - if it is, then we can slice everything after the end position and denote as 'what it is'
# write the output to a new CSV file
#     contain all the information from the good hits, with extra column for organism, and gene name ('what it is')
#
#
#
# 2.
# git hub
#     next project is similar to this, but has way more code files that call on each other, so keeping the versions straight will get tricky
# sign up for a github account - go through the tutorial
